# %%
import sys
import os

try:
    import morphman
    print("✅ Success: morphman is installed!")
    print(f"📍 Location: {morphman.__file__}")
except ImportError:
    print("❌ Error: morphman is NOT found in this environment.")
    print(f"Current Python Executable: {sys.executable}")
# Out:
# ❌ Error: morphman is NOT found in this environment.
# Current Python Executable: c:\Users\anwes\Documents\GitHub\internship_2026\.venv\Scripts\python.exe
